# %%
from IPython.display import HTML, Image, display

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import sys
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from random import choices
from scipy import stats

sys.path.insert(0, '../src/')

# %%
ovr_type = pd.read_csv('../viz/Analysis/Crime/ovr_Type_dist.csv',index_col=[0])
ovr_charge = pd.read_csv('../viz/Analysis/Crime/ovr_Charge_dist.csv',index_col=[0])

type_detailed = pd.read_csv('../viz/Analysis/Crime/div_Type_detailed.csv',index_col=[0,1])
charge_detailed = pd.read_csv('../viz/Analysis/Crime/div_Charge_detailed.csv',index_col=[0,1])

# %% [markdown]
# # Compare proportion of crime types with the arrest rates of crime types

# %%
display(Image('../viz/Analysis/Crime/div_Type_dist.png'))

# %%
display(Image('../viz/Analysis/Arrests/div_Arrest_Charge_dist.png'))

# %%
display(Image('../viz/Analysis/Crime/div_Charge_dist.png'))

# %%
display(Image('../viz/Analysis/Arrests/div_Arrest_Type_dist.png'))
